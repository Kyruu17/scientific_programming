# %%
# Week 01 Challenge

# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import os
import platform
import socket
from platform import python_version
from datetime import datetime

# Create a numpy array with random numbers
random_numbers = np.random.rand(100)
print(random_numbers)

# Calculate quartiles
quartiles = np.percentile(random_numbers, [25, 50, 75])
print("Quartiles:", quartiles)

# Create a histogram
plt.hist(random_numbers, bins=10)
plt.title("Histogram of Random Numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# Create a boxplot
plt.boxplot(random_numbers)
plt.title("Boxplot of Random Numbers")
plt.ylabel("Value")
plt.show()

# Display system information
print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# [0.31929883 0.17074774 0.97268026 0.82356831 0.17885888 0.63098563
#  0.54907675 0.1761723  0.75621761 0.87616871 0.28477165 0.2465592
#  0.76356753 0.6426078  0.09952179 0.75074636 0.56915788 0.23934087
#  0.30720608 0.20158367 0.81904647 0.56869999 0.44928301 0.5774221
#  0.46100065 0.07578817 0.19991042 0.48320654 0.95559207 0.69298282
#  0.61339336 0.13744981 0.42659034 0.22130448 0.06657694 0.52045852
#  0.33499212 0.18899342 0.29568773 0.31086453 0.46459795 0.5581085
#  0.95072006 0.15241551 0.79186981 0.91410631 0.69923055 0.60465014
#  0.15301999 0.78064396 0.85590807 0.507631   0.58091814 0.91189551
#  0.94370966 0.93740535 0.48826851 0.08835868 0.68661228 0.16728358
#  0.45691866 0.1890502  0.3236219  0.16252453 0.91820544 0.50965934
#  0.50047869 0.88491688 0.59426835 0.20116062 0.19819131 0.94319061
#  0.487863   0.30212678 0.29219399 0.44830671 0.65484135 0.74948787
#  0.11004745 0.79246808 0.43690878 0.34383269 0.91512477 0.45229519
#  0.09658457 0.93544812 0.90889405 0.12624265 0.35529237 0.43871169
#  0.07381563 0.99133903 0.24197033 0.23325147 0.61944645 0.13325402
#  0.13541977 0.63832669 0.82155463 0.52491827]
# Quartiles: [0.23026472 0.48553477 0.74980249]
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2025-02-22 13:54:34
# Python Version: 3.11.11
# -----------------------------------
